# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
from scipy import stats
from datetime import datetime
# Out:
# /Users/anamaria/.pyenv/versions/itam_intro_to_ds/lib/python3.7/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df = pd.read_csv('../data/incidentes-viales-c5.csv')

# %%
def date_transformation(col, df):
    """
    Conduct relevant transformations to date variables.
        args:
            col (string): name of date column that will be transformed.
            df (dataframe): df that will be transformed.
        returns:
            df (dataframe): resulting df with cleaned date column.
    """
    fechas_inicio = df[col].str.split("/", n=2,expand=True)
    df['dia_inicio'] = fechas_inicio[0]
    df['mes_inicio'] = fechas_inicio[1]
    df['anio_inicio'] = fechas_inicio[2]

    df['anio_inicio'] = df['anio_inicio'].replace(['19'],'2019')
    df['anio_inicio'] = df['anio_inicio'].replace(['18'],'2018')
    
    cyc_lst = ["dia_inicio", "mes_inicio"]
    for val in cyc_lst:
        cyclic_trasformation(df, val)
    
    df.drop(['dia_inicio','mes_inicio'], axis=1, inplace=True)

    return df

# %%
def hour_transformation(col, df):
    """
    """

    df[col] = pd.to_timedelta(df[col],errors='ignore')
    hora_inicio = df[col].str.split(":", n=2,expand=True)
    df['hora_inicio'] = hora_inicio[0]
    df['min_inicio'] = hora_inicio[1]
    df['hora_inicio'] = round(df['hora_inicio'].apply(lambda x: float(x)),0)
    
    cyc_lst = ["hora_inicio"]
    for val in cyc_lst:
        cyclic_trasformation(df, val)
    
    df.drop(['hora_inicio','min_inicio'], axis=1, inplace=True)


    return df

# %%
def cyclic_trasformation(df, col):
    """
    Conduct relevant cyclical hour transformations to cos and sin coordinates.
        args:
            col (string): name of  column that will be transformed into cyclical hr.
            df (dataframe): df that will be transformed.
        returns:
            df (dataframe): resulting df with cyclical column.
    """
    if "hora" in col:
        div=24    
    elif "dia" in col:
        div= 30.4
    elif "mes" in col:
        div=12
    
    df[col + '_sin'] = np.sin(2*np.pi*df[col].apply(lambda x: float(x))/div)
    df[col+ '_cos'] = np.cos(2*np.pi*df[col].apply(lambda x: float(x))/div)
    
    return df

# %%
date_transformation("fecha_creacion", df)
# Out:
#                    folio fecha_creacion hora_creacion dia_semana  \
# 0        GA/160123/05714     23/01/2016      22:35:04     Sábado
# 1        AO/160123/05826     23/01/2016      22:50:49     Sábado
# 2        C4/160124/02187     24/01/2016      09:40:11    Domingo
# 3        C4/160124/05723     24/01/2016      22:40:57    Domingo
# 4        C4/160124/01334     24/01/2016      04:25:15    Domingo
# ...                  ...            ...           ...        ...
# 1383133  GA/201022/03443     22/10/2020      16:17:05     Jueves
# 1383134  GA/201022/03492     22/10/2020      16:29:13     Jueves
# 1383135  C5/201022/02030     22/10/2020      12:00:26     Jueves
# 1383136  C5/201022/02039     22/10/2020      12:01:25     Jueves
# 1383137  C5/201022/03364     22/10/2020      16:05:47     Jueves
#
#                                              codigo_cierre fecha_cierre  \
# 0        (A) La unidad de atención a emergencias fue de...   24/01/2016
# 1        (A) La unidad de atención a emergencias fue de...   24/01/2016
# 2        (N) La unidad de atención a emergencias fue de...   24/01/2016
# 3        (N) La unidad de atención a emergencias fue de...   24/01/2016
# 4        (A) La unidad de atención a emergencias fue de...   24/01/2016
# ...                                                    ...          ...
# 1383133  (A) La unidad de atención a emergencias fue de...   22/10/2020
# 1383134  (A) La unidad de atención a emergencias fue de...   22/10/2020
# 1383135  (D) El incidente reportado se registró en dos ...   22/10/2020
# 1383136  (D) El incidente reportado se registró en dos ...   22/10/2020
# 1383137  (D) El incidente reportado se registró en dos ...   22/10/2020
#
#          año_cierre mes_cierre hora_cierre    delegacion_inicio  ... mes  \
# 0              2016      Enero    00:21:08  VENUSTIANO CARRANZA  ...   1
# 1              2016      Enero    04:40:37           CUAJIMALPA  ...   1
# 2              2016      Enero    11:13:03              TLALPAN  ...   1
# 3              2016      Enero    22:55:51  MAGDALENA CONTRERAS  ...   1
# 4              2016      Enero    05:03:59       MIGUEL HIDALGO  ...   1
# ...             ...        ...         ...                  ...  ...  ..
# 1383133        2020    Octubre    16:58:49    GUSTAVO A. MADERO  ...  10
# 1383134        2020    Octubre    18:54:22  VENUSTIANO CARRANZA  ...  10
# 1383135        2020    Octubre    12:02:30         AZCAPOTZALCO  ...  10
# 1383136        2020    Octubre    12:05:59  VENUSTIANO CARRANZA  ...  10
# 1383137        2020    Octubre    16:10:13           IZTAPALAPA  ...  10
#
#          anio_inicio  dia_inicio_sin dia_inicio_cos mes_inicio_sin  \
# 0               2016       -0.999146       0.041325       0.500000
# 1               2016       -0.999146       0.041325       0.500000
# 2               2016       -0.969400       0.245485       0.500000
# 3               2016       -0.969400       0.245485       0.500000
# 4               2016       -0.969400       0.245485       0.500000
# ...              ...             ...            ...            ...
# 1383133         2020       -0.986361      -0.164595      -0.866025
# 1383134         2020       -0.986361      -0.164595      -0.866025
# 1383135         2020       -0.986361      -0.164595      -0.866025
# 1383136         2020       -0.986361      -0.164595      -0.866025
# 1383137         2020       -0.986361      -0.164595      -0.866025
#
#         mes_inicio_cos hora_inicio  min_inicio hora_inicio_sin  \
# 0             0.866025        22.0          35   -5.000000e-01
# 1             0.866025        22.0          50   -5.000000e-01
# 2             0.866025         9.0          40    7.071068e-01
# 3             0.866025        22.0          40   -5.000000e-01
# 4             0.866025         4.0          25    8.660254e-01
# ...                ...         ...         ...             ...
# 1383133       0.500000        16.0          17   -8.660254e-01
# 1383134       0.500000        16.0          29   -8.660254e-01
# 1383135       0.500000        12.0          00    1.224647e-16
# 1383136       0.500000        12.0          01    1.224647e-16
# 1383137       0.500000        16.0          05   -8.660254e-01
#
#          hora_inicio_cos
# 0               0.866025
# 1               0.866025
# 2              -0.707107
# 3               0.866025
# 4               0.500000
# ...                  ...
# 1383133        -0.500000
# 1383134        -0.500000
# 1383135        -1.000000
# 1383136        -1.000000
# 1383137        -0.500000
#
# [1383138 rows x 27 columns]

# %%
hour_transformation("hora_creacion", df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.pyenv/versions/itam_intro_to_ds/lib/python3.7/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     367         try:
# --> 368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
#
# KeyError: 'min_inicio'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-6b4db7d3efe5> in <module>
# ----> 1 hour_transformation("hora_creacion", df)
#
# <ipython-input-81-ec8a1e38af57> in hour_transformation(col, df)
#      13         cyclic_trasformation(df, val)
#      14
# ---> 15     df.drop('hora_inicio','min_inicio')
#      16
#      17
#
# ~/.pyenv/versions/itam_intro_to_ds/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4168             level=level,
#    4169             inplace=inplace,
# -> 4170             errors=errors,
#    4171         )
#    4172
#
# ~/.pyenv/versions/itam_intro_to_ds/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3872             if index is not None or columns is not None:
#    3873                 raise ValueError("Cannot specify both 'labels' and 'index'/'columns'")
# -> 3874             axis_name = self._get_axis_name(axis)
#    3875             axes = {axis_name: labels}
#    3876         elif index is not None or columns is not None:
#
# ~/.pyenv/versions/itam_intro_to_ds/lib/python3.7/site-packages/pandas/core/generic.py in _get_axis_name(cls, axis)
#     372     @classmethod
#     373     def _get_axis_name(cls, axis: Axis) -> str:
# --> 374         axis_number = cls._get_axis_number(axis)
#     375         return cls._AXIS_ORDERS[axis_number]
#     376
#
# ~/.pyenv/versions/itam_intro_to_ds/lib/python3.7/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
# --> 370             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#     371
#     372     @classmethod
#
# ValueError: No axis named min_inicio for object type DataFrame
